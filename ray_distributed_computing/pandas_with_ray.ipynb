# %%
import modin.pandas as pd
import ray

ray.init()
# Out:
# 2022-04-05 10:50:28,975	INFO services.py:1412 -- View the Ray dashboard at http://127.0.0.1:8265
# {'node_ip_address': '127.0.0.1',
#  'raylet_ip_address': '127.0.0.1',
#  'redis_address': None,
#  'object_store_address': 'tcp://127.0.0.1:65040',
#  'raylet_socket_name': 'tcp://127.0.0.1:65249',
#  'webui_url': '127.0.0.1:8265',
#  'session_dir': 'C:\\Users\\user\\AppData\\Local\\Temp\\ray\\session_2022-04-05_10-50-26_281871_34600',
#  'metrics_export_port': 65050,
#  'gcs_address': '127.0.0.1:62262',
#  'address': '127.0.0.1:62262',
#  'node_id': '68bfd1d6b92d1c21a663c6a1069504ccb5752cba8e1871f56e8baa81'}

# %%
df = pd.read_csv("data/midyear_population_age_country_code.csv")

# %%
df[df["sex"] == "Male"]
# Out:
#         country_code country_name  year   sex  max_age  population_age_0  \
# 1                 TW       Taiwan  1994  Male      100            167664
# 2                 GR       Greece  2032  Male      100             45061
# 3                 RS       Russia  2045  Male      100            627853
# 4                 MZ   Mozambique  1989  Male      100            257640
# 6                 GV       Guinea  1978  Male       97             87702
# ...              ...          ...   ...   ...      ...               ...
# 3058270           GH        Ghana  2036  Male      100            511511
# 3058275           GA   Gambia The  1986  Male       99             18245
# 3058276           AN      Andorra  2037  Male      100               334
# 3058278           NH      Vanuatu  2027  Male      100              3372
# 3058279           UG       Uganda  2030  Male      100           1011560
#
#          population_age_1  population_age_2  population_age_3  \
# ...

# %%
df[df["max_age"] < 100]
# Out:
#         country_code              country_name  year     sex  max_age  \
# 6                 GV                    Guinea  1978    Male       97
# 20                QA                     Qatar  1997    Male       99
# 33                GJ                   Grenada  2010  Female       99
# 44                KR                  Kiribati  2036    Male       98
# 57                TK  Turks and Caicos Islands  2010    Male       96
# ...              ...                       ...   ...     ...      ...
# 3058211           GY                    Guyana  1995    Male       99
# 3058237           AN                   Andorra  2000  Female       98
# 3058257           NG                     Niger  1987    Male       98
# 3058274           AF               Afghanistan  1982  Female       99
# 3058275           GA                Gambia The  1986    Male       99
#
#          population_age_0  population_age_1  population_age_2  \
# 6                   87702             78608             73294
# ...
